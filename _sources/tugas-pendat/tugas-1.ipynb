# %% [markdown]
# # Tugas - 1 : Menghitung jarak

# %% [markdown]
# Link colab tugas 1 :
#
# https://colab.research.google.com/drive/1rItMY8GGZjzDNHAQIYJ2b04inQ0vRnMg#scrollTo=2XLY4rjvIRTb

# %%
import numpy as np
import pandas as pd
import seaborn as sb
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Iqbalsuryaa/datamining/main/milknew.csv")
print(data)
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0     6.6          35      1     0     1          0     254    high
# 1     6.6          36      0     1     0          1     253    high
# 2     8.5          70      1     1     1          1     246     low
# 3     9.5          34      1     1     0          1     255     low
# 4     6.6          37      0     0     0          0     255  medium
# ...   ...         ...    ...   ...   ...        ...     ...     ...
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low
#
# [1059 rows x 8 columns]

# %%
data
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0     6.6          35      1     0     1          0     254    high
# 1     6.6          36      0     1     0          1     253    high
# 2     8.5          70      1     1     1          1     246     low
# 3     9.5          34      1     1     0          1     255     low
# 4     6.6          37      0     0     0          0     255  medium
# ...   ...         ...    ...   ...   ...        ...     ...     ...
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low
#
# [1059 rows x 8 columns]

# %%
def dt1(i,j):
  P = 9
  Q = 0
  for col in ["pH", "Temprature", "Taste", "Odor", "Turbidity", "Colour"]:
    if data[col][i] == data[col][j]:
      Q += 1
  return (P-Q)/P

# %%
print(dt1(1,2))
print(dt1(1,3))
print(dt1(1,4))
# Out:
# 0.7777777777777778
# 0.7777777777777778
# 0.7777777777777778

# %%
def dt2(i,j,h):
  result = 0
  for col in ["pH", "Temprature", "Taste", "Odor", "Turbidity", "Colour"]:
    result = math.pow(abs(data[col][i] - data[col][j]), h)
  return result**(1/h)

# %%
print(dt2(1,2,1))
print(dt2(1,3,1))
print(dt2(1,4,1))
# Out:
# 7.0
# 2.0
# 2.0
